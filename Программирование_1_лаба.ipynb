# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicole9080/lab_1/blob/main/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_1_%D0%BB%D0%B0%D0%B1%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Задание task_01_01.
# Выполнилa: Манидарова Н.Ч.
# Группа: ЦИБ-251

a = int(input("a="))
b = int(input("b="))
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(round(a % b ,2))
print(a ** b)
print(a < b)
print(a <= b)
print(a > b)
print(a >= b)
print(a != b)
print(a == b)
# Out:
# a=6
# b=5
# 11
# 1
# 30
# 1.2
# 1
# 1
# 7776
# False
# False
# True
# True
# True
# False

# %%
# Задание task_01_02.
# Выполнилa: Манидарова Н.Ч.
# Группа: ЦИБ-251

# Правильный способ ввода чисел
x = int(input("x: "))
y = int(input("y: "))
z = int(input("z: "))
# Вычисление выражения
f = ((x ** 5 + 7) / (abs(-6) * y) ** (1/3)) / (7 - z % y)
# Jкругление
res = round(f, 3)
print(res)
# Out:
# x: 1
# y: 2
# z: 3
# 0.582

# %%
# Задание task_01_03.
# Выполнилa: Манидарова Н.Ч.
# Группа: ЦИБ-251

r1 = float(input("Сопротивление первого проводника: "))
r2 = float(input("Сопротивление второго проводника: "))
r = r1 + r2
print(f"Общее сопротивление цепи: {round(r , 2)}")
# Out:
# Сопротивление первого проводника: 1
# Сопротивление второго проводника: 2
# Общее сопротивление цепи: 3.0

# %%
# Задание task_01_04.
# Выполнилa: Манидарова Н.Ч.
# Группа: ЦИБ-251


# Двузначное число
num2 = int(input('Введите двузначное число: '))
# Трехзначное число
num3 = int(input('Введите трёхзначное число: '))

# 1-я цифра числа 'num2'
num2_1 = num2 // 10
# 2-я цифра числа 'num2'
num2_2 = num2 % 10

# Сумма цифр числа 'num2'
num2_s = num2_1+num2_2
# Произведение цифр числа 'num2'
num2_p = num2_1-num2_2

# 1-я цифра числа 'num3'
num3_1 = num3 // 100
# 2-я цифра числа 'num3'
num3_2 = (num3 // 10) % 10
# 3-я цифра числа 'num3'
num3_3 = num3 % 10

# Сумма цифр числа 'num3'
num3_s = num3_1+num3_2+num3_3
# Произведение цифр числа 'num3'
num3_p = num3_1-num3_2-num3_3

# Вывод результата
print('Сумма и произведение цифр трёхзначного числа: ' , num2_s ,num2_p)
print('Сумма и произведение цифр трёхзначного числа: ' , num3_s ,num3_p)
# Out:
# Введите двузначное число: 12
# Введите трёхзначное число: 456
# Сумма и произведение цифр трёхзначного числа:  3 -1
# Сумма и произведение цифр трёхзначного числа:  15 -7

# %%
# Задание task_01_05.
# Выполнилa: Манидарова Н.Ч.
# Группа: ЦИБ-251

# Количество минут
m = int(input("Введите количество минут, прошедших с начала суток: "))

# Количество часов, прошедших с начала суток
h = m // 60

# Количество минут, прошедших с момента начала последнего часа
m2 = m % 60

print("Количество минут, прошедшее с начала суток:", m)
print("Количество часов, прошедших с начала суток:", h)
print("Количество минут, прошедших с момента начала последнего часа:", m2)
# Out:
# Введите количество минут, прошедших с начала суток: 76
# Количество минут, прошедшее с начала суток: 76
# Количество часов, прошедших с начала суток: 1
# Количество минут, прошедших с момента начала последнего часа: 16

# %%
# Задание task_01_06.
# Выполнилa: Манидарова Н.Ч.
# Группа: ЦИБ-251


a = int(input('Введите a= :'))
b = int(input('Введите b= :'))
m = int(input('Введите m= :'))
n = int(input('Введите n= :'))

x = -b/a

is_ok = m <= x <= n

print("Попадает:", is_ok)
# Out:
# Введите a= :2
# Введите b= :7
# Введите m= :89
# Введите n= :8
# Попадает: False

# %%
# Задание task_01_07.
# Выполнилa: Манидарова Н.Ч.
# Группа: ЦИБ-251

team = input("Введите название команды: ")
print(f'{team} -чемпион!')
daches='-' *len(team)
print(daches)

# Название команды в нижнем регистре
team_lowercase = team.lower()
print("Символов в названии команды:", len(team))
print('Буква "п" есть: ', "п" in team_lowercase)
print('Количество букв "а": ', team_lowercase.count("а"))
# Out:
# Введите название команды: Спартак
# Спартак -чемпион!
# -------
# Символов в названии команды: 7
# Буква "п" есть:  True
# Количество букв "а":  2

# %%
# Задание task_01_08.
# Выполнилa: Манидарова Н.Ч.
# Группа: ЦИБ-251


# Название государства
country = input('Введите название государства: ')
# Название столицы
capital = input('Введите название столицы: ')
print(f'Государство - {country} , столица - {capital}')
# Out:
# Введите название государства: Россия
# Введите название столицы: Москва
# Государство - Россия , столица - Москва

# %%
# Задание task_01_09.
# Выполнилa: Манидарова Н.Ч.
# Группа: ЦИБ-251

word = "объектно-ориентированный"

w1 = word[0:6]  # (слово объект)
w2 = word[9:17] #(слово ориентир)
w3 = word[14:17] #(слово тир)
w4 = word[4]+ word[9]+ word[14] # (слово кот)
w5 = word[10] + word[3]+ word[6]+ word[5]+word[19]#(слово рента)

print(w1, w2, w3, w4, w5, sep="\n")
# Out:
# объект
# ориентир
# тир
# кот
# рента

# %%
# Задание task_01_10.
# Выполнилa: Манидарова Н.Ч.
# Группа: ЦИБ-251

# Создать 2 пустых списка
a = []
b = []
# Добавить 2 вещественных числа (4.5 и 3.4) в список 'a' с помощью append
a.append(4.5)
a.append(3.4)
# Добавить 2 вещественных числа (8.7, 1.3) в список 'a' с помощью extend
a.extend([8.7])
a.extend([1.3])
# Добавить 2 вещественных числа (14.5, 3.4) в список 'b' с помощью append
b.append(14.5)
b.append(3.4)

# Добавить 2 вещественных числа (8.7, 11.3) в список 'b'с помощью extend
b.extend([8.7])
b.extend([11.3])

# Вставить целое число 100 на 2-е и 4-е место списка 'a'
a.insert(1,100)
a.insert(3,100)

# Вставить целое число 200 на 1-е и 3-е место списка 'b'
b.insert(0,200)
b.insert(3,200)

# Вывести списки на экран
print("Исходные списки:")
print('1-й:', a)
print('2-й:', b)

# Удалить первые элементы из списков 'a' и 'b'
del a[0]
del b[0]

# Удалить элемент 100 из списка 'a'
a.remove(100)
b.remove(200)

# Вывести списки на экран
print("\nПосле удалений:")
print('1-й:', a)
print('2-й:', b)

# Создать множества из списков 'a' и 'b', а также их пересечение
sa = set(a)
sb = set(b)
sa_and_sb = sa&sb

# Вывести экран уникальные элементы каждого списка и общие
print("\nУникальные элементы:")
print("1-й: " , a)
print('2-й:', b)
print("общие:", sa_and_sb)

# Соединить списки 'a' и 'b'
c = a+b

# Отсортировать список 'c' по возрастанию и убыванию
c_asc = sorted(c)
c_desc = sorted(c,reverse=True)

# Среднее арифметическое элементов списка 'c', расположенных на четных местах
sr_ar = sum(c[1::2]) / len(c[1::2])

# Среднее геометрическое элементов списка 'c', расположенных на нечетных местах
odd_elements = (c[0::2])
product = 1
for elem in odd_elements:
    product *= elem
sr_geom = product ** (1 / len(odd_elements))

# Максимальный и минимальный элементы
c_max = max(c)
c_min = min(c)

# Вывести результаты на экран
print("\nИтоговые:")
print("3-й:", c)
print('Сортировка (возр.): ', c_asc)
print('Сортировка (убыв.): ', c_desc)
print(f"Ср. арифм. = {sr_ar:.2f}, ср. геометр. = {sr_geom:.2f}")
print(f"Макс. и мин.: {c_max} {c_min}")
# Out:
# Исходные списки:
# 1-й: [4.5, 100, 3.4, 100, 8.7, 1.3]
# 2-й: [200, 14.5, 3.4, 200, 8.7, 11.3]
#
# После удалений:
# 1-й: [3.4, 100, 8.7, 1.3]
# 2-й: [14.5, 3.4, 8.7, 11.3]
#
# Уникальные элементы:
# 1-й:  [3.4, 100, 8.7, 1.3]
# 2-й: [14.5, 3.4, 8.7, 11.3]
# общие: {8.7, 3.4}
#
# Итоговые:
# 3-й: [3.4, 100, 8.7, 1.3, 14.5, 3.4, 8.7, 11.3]
# Сортировка (возр.):  [1.3, 3.4, 3.4, 8.7, 8.7, 11.3, 14.5, 100]
# Сортировка (убыв.):  [100, 14.5, 11.3, 8.7, 8.7, 3.4, 3.4, 1.3]
# Ср. арифм. = 29.00, ср. геометр. = 7.82
# Макс. и мин.: 100 1.3

# %%
# Задание task_01_11.
# Выполнилa: Манидарова Н.Ч.
# Группа: ЦИБ-251

# В данной задаче все значения задаются в коде (без input())

# 1. Создание словаря
# Создать пустой словарь
info = {}

# Добавить значения для ключей "фио", "дата_рождения", "место_рождения"
info['фио'] = 'Реджистер Эмма Чарльзовна'
info['дата_рождения']= '18.09.2007'
info["место_рождения"]= 'Сан-Диего'

# Напечатать словарь
print(info)

# Создать ключ "хобби" со значением = список из строк -
# наименований хобби (например "плавание" и т.д.)
info["хобби"]= ['Волонтерство','Организация мероприятий']

# Добавить "программирование" в список хобби
info["хобби"].append("программирование")

# Создать ключ "животные" со значением = кортеж из строк -
# имен домашних животных (например "кошка Мурка" и т.д.)
info["животные"]= ('кошка Джуди', 'кошка Элли')

# Создать ключ "ЕГЭ" и поместить в него пустой словарь
info['ЕГЭ']={}

# В словарь info["ЕГЭ"] добавить информацию о сданных экзаменах,
# где ключ - наименование предмета, а значение - количество баллов
info["ЕГЭ"]["Литература"] = 98
info["ЕГЭ"]["Английский язык"] = 92
info["ЕГЭ"]["Русский язык"] = 91

# Добавить экзамен, который не был сдан, после чего удалить его
info["ЕГЭ"]['Математика']=0
del info["ЕГЭ"]['Математика']

# Создать ключ "вузы" и поместить в него пустой словарь
info["вузы"]={}

# В словарь info["вузы"] добавить информацию о вузах,
# где ключ - аббревиатура вуза, а значение -
# количество баллов для специальности, на которую хотели поступить
# Удалите комментарий и допишите код
info["вузы"]["РАНХИГС"] = 260
info["вузы"]["РУДН"] = 243
info["вузы"]["Финансовый университет"] = 270

# 2. Вывод на экран
print("Данные:")
# Получившийся словарь
print(info)

# Список экзаменов ЕГЭ в алфавитном порядке
# (используйте метод ``keys()``, преобразовав результат в кортеж)
exams = tuple(sorted(info["ЕГЭ"].keys()))
print("Предметы:", ', '.join(exams))

# Список вузов в алфавитном порядке
uni = tuple(sorted(info["вузы"].keys()))
print("Вузы:", ', '.join(uni))

# 3. Ответы на вопросы
print("\nОтветы на вопросы:")

# Выделить имя из info["фио"]
name = info["фио"].split()[1]
# Начинается на гласную? (True/False)
starts_with_vowel = name[0].lower() in "аеёиоуыэюя"
print("* мое имя начинается на гласную букву:", starts_with_vowel)

# Выделить месяц из info["дата_рождения"]
month = info["дата_рождения"].split('/')
# Родился зимой или летом? (True/False)
born_in_winter_or_summer = month in [12, 1, 2, 6, 7, 8]
print("* родился летом или зимой:", born_in_winter_or_summer)

# Количество хобби и первое из них
hobbies_count = len(info["хобби"])
first_hobby = info["хобби"][0]
print("* у меня {} хобби, первое \"{}\"".format(hobbies_count, first_hobby))


# Количество сданных экзаменов
exams_count = len(info["ЕГЭ"])
print("* после окончания школы сдавал {} экз.".format(exams_count))

# Сумма баллов по экзаменам
sum_mark = sum(info["ЕГЭ"].values())
print("* сумма баллов = {}".format(sum_mark))

# Максимальный балл среди сданных
max_mark = max(info["ЕГЭ"].values())
print("* макс. балл = {}".format(max_mark))


total_exam_score = sum_mark
vuz_count = sum(
    int(total_exam_score >= passing_score)
    for passing_score in info["вузы"].values()
)
print("* кол-во вузов в которые прохожу: {}".format(vuz_count))
# Out:
# {'фио': 'Реджистер Эмма Чарльзовна', 'дата_рождения': '18.09.2007', 'место_рождения': 'Сан-Диего'}
# Данные:
# {'фио': 'Реджистер Эмма Чарльзовна', 'дата_рождения': '18.09.2007', 'место_рождения': 'Сан-Диего', 'хобби': ['Волонтерство', 'Организация мероприятий', 'программирование'], 'животные': ('кошка Джуди', 'кошка Элли'), 'ЕГЭ': {'Литература': 98, 'Английский язык': 92, 'Русский язык': 91}, 'вузы': {'РАНХИГС': 260, 'РУДН': 243, 'Финансовый университет': 270}}
# Предметы: Английский язык, Литература, Русский язык
# Вузы: РАНХИГС, РУДН, Финансовый университет
#
# Ответы на вопросы:
# * мое имя начинается на гласную букву: True
# * родился летом или зимой: False
# * у меня 3 хобби, первое "Волонтерство"
# * после окончания школы сдавал 3 экз.
# * сумма баллов = 281
# * макс. балл = 98
# * кол-во вузов в которые прохожу: 3
